# %%
# %cd /content
# !git clone https://github.com/REICHIYAN/llm_infra_lab.git
# %cd llm_infra_lab
# Out:
# /content
# Cloning into 'llm_infra_lab'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 24 (delta 0), reused 24 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 9.87 KiB | 9.87 MiB/s, done.
# /content/llm_infra_lab

# %%
# !pip install -r requirements.txt

# %%
# !pwd
# !ls
# Out:
# /content/llm_infra_lab
# jax  README.md	       scripts	terraform  training
# k8s  requirements.txt  serving	tests

# %%
# %cd /content/llm_infra_lab
# !PYTHONPATH=. pytest -q
# Out:
# /content/llm_infra_lab
# .....                                                                    [100%]
# 5 passed in 2.88s
